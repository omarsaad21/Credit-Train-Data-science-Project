# %% [markdown]
# importing required libraries

# %%
import pandas as pd
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading Data

# %%
# Importing the dataset
df=pd.read_csv("D:\My Projects\Final Project\credit_train.csv",na_values=['x'])
df
# Out:
#        Unnamed: 0      ID Customer_ID    Month       Name   Age          SSN  \
# 0           46184   74905  CUS_0xbbda   August  le Stevem    50  598-28-8368
# 1           63927  101520  CUS_0x1e51     July   Raymondl    32  887-23-0031
# 2           65974  104591  CUS_0x1765     June     Harryw    32  966-30-5287
# 3           68006  107639  CUS_0x751c     June   Jessican    19  220-63-1416
# 4           84461  132322  CUS_0x1c59      May       Dayz    41  277-13-7658
# ...           ...     ...         ...      ...        ...   ...          ...
# 54735       47297   76578  CUS_0xb443  January    Kerbere    21    #F%$D@*&8
# 54736       14571   27488  CUS_0x36ed    March     Carewn    32  398-22-8099
# 54737       43014   70151  CUS_0x204b     June       Nius    31  893-44-1748
# 54738       85052  133209  CUS_0x3c97    April  Tetsushiz    44  856-06-6147
# 54739       67901  107482  CUS_0xc150      May    Josepht  7255  154-13-2333
#
# ...

# %% [markdown]
# ## DATA UNDERSTANDING

# %%
# Showing the first 5 rows
df.head(5)
# Out:
#    Unnamed: 0      ID Customer_ID   Month       Name Age          SSN  \
# 0       46184   74905  CUS_0xbbda  August  le Stevem  50  598-28-8368
# 1       63927  101520  CUS_0x1e51    July   Raymondl  32  887-23-0031
# 2       65974  104591  CUS_0x1765    June     Harryw  32  966-30-5287
# 3       68006  107639  CUS_0x751c    June   Jessican  19  220-63-1416
# 4       84461  132322  CUS_0x1c59     May       Dayz  41  277-13-7658
#
#      Occupation Annual_Income  Monthly_Inhand_Salary  ...  Credit_Mix  \
# 0       Manager      72099.14            5842.350694  ...        Good
# 1  Entrepreneur      17443.94            1714.661667  ...         Bad
# 2       _______     15186.175            1527.514583  ...    Standard
# 3    Accountant     177696.92           15090.076667  ...        Good
# 4        Doctor     19188.055            1358.004583  ...           _
#
#    Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# ...

# %%
#show last 5 rows
df.tail(5)
# Out:
#        Unnamed: 0      ID Customer_ID    Month       Name   Age          SSN  \
# 54735       47297   76578  CUS_0xb443  January    Kerbere    21    #F%$D@*&8
# 54736       14571   27488  CUS_0x36ed    March     Carewn    32  398-22-8099
# 54737       43014   70151  CUS_0x204b     June       Nius    31  893-44-1748
# 54738       85052  133209  CUS_0x3c97    April  Tetsushiz    44  856-06-6147
# 54739       67901  107482  CUS_0xc150      May    Josepht  7255  154-13-2333
#
#        Occupation Annual_Income  Monthly_Inhand_Salary  ...  Credit_Mix  \
# 54735      Doctor    21271789.0           12452.330000  ...    Standard
# 54736   Developer       28452.8            2267.066667  ...           _
# 54737    Mechanic      52256.67            4322.722500  ...           _
# 54738  Journalist      9741.195            1097.766250  ...           _
# 54739      Lawyer       31016.6            2653.716667  ...        Good
#
# ...

# %%
# Showing the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN',
#        'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Showing the value counts
df['Credit_Score'].value_counts()
# Out:
# Credit_Score
# 0.0    15870
# 1.0     9718
# Name: count, dtype: int64

# %%
# Show the value counts
df['Customer_ID'].value_counts()
# Out:
# Customer_ID
# CUS_0x219c    8
# CUS_0x7403    8
# CUS_0xb74c    8
# CUS_0x8bce    8
# CUS_0x6578    8
#              ..
# CUS_0xb529    1
# CUS_0xae70    1
# CUS_0xc3a6    1
# CUS_0x185e    1
# CUS_0x1a96    1
# Name: count, Length: 12479, dtype: int64

# %%
# Drop the columns
df.drop(columns=['Customer_ID','ID'],inplace=True)

# %%
# Drop the column
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# Convert 'Age' to numeric, coerce errors (invalid strings will be turned into NaN)
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# Filter the dataset for ages between 18 and 60
df_filtered = df[(df['Age'] >= 18) & (df['Age'] <= 60)]

# Sort the filtered data by Age
df_sorted = df_filtered.sort_values(by='Age')

# Check the result (optional)
print(df_sorted[['Age']].head())  # Display the first few rows of the Age column to confirm
# Out:
#         Age
# 54072  18.0
# 54083  18.0
# 51664  18.0
# 30429  18.0
# 41567  18.0

# %%
df = df.drop(54739, axis=0)

# %%
df['Age'].max
# Out:
# <bound method Series.max of 0        50.0
# 1        32.0
# 2        32.0
# 3        19.0
# 4        41.0
#          ...
# 54734    48.0
# 54735    21.0
# 54736    32.0
# 54737    31.0
# 54738    44.0
# Name: Age, Length: 54739, dtype: float64>

# %%
df
# Out:
#          Month               Name   Age          SSN     Occupation  \
# 0       August          le Stevem  50.0  598-28-8368        Manager
# 1         July           Raymondl  32.0  887-23-0031   Entrepreneur
# 2         June             Harryw  32.0  966-30-5287        _______
# 3         June           Jessican  19.0  220-63-1416     Accountant
# 4          May               Dayz  41.0  277-13-7658         Doctor
# ...        ...                ...   ...          ...            ...
# 54734     June  Kiyoshi Takenakar  48.0  216-36-8255  Media_Manager
# 54735  January            Kerbere  21.0    #F%$D@*&8         Doctor
# 54736    March             Carewn  32.0  398-22-8099      Developer
# 54737     June               Nius  31.0  893-44-1748       Mechanic
# 54738    April          Tetsushiz  44.0  856-06-6147     Journalist
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          72099.14            5842.350694                  4
# ...

# %%
# Showing the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54739 entries, 0 to 54738
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     54739 non-null  object
#  1   Name                      49212 non-null  object
#  2   Age                       52007 non-null  float64
#  3   SSN                       54739 non-null  object
#  4   Occupation                54739 non-null  object
#  5   Annual_Income             54739 non-null  object
#  6   Monthly_Inhand_Salary     54739 non-null  float64
#  7   Num_Bank_Accounts         54739 non-null  int64
#  8   Num_Credit_Card           54739 non-null  int64
#  9   Interest_Rate             54739 non-null  int64
#  10  Num_of_Loan               54739 non-null  object
#  11  Type_of_Loan              48487 non-null  object
#  12  Delay_from_due_date       54739 non-null  int64
# ...

# %%
# check shape
df.shape
# Out:
# (54739, 26)

# %%
# check duplicate
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Month', 'Name', 'Age', 'SSN', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# describe the dataset
df.describe()
# Out:
#                 Age  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  52007.000000           54739.000000       54739.000000
# mean     108.760263            4205.135169          16.634867
# std      678.175572            3186.288175         114.925772
# min     -500.000000             303.645417          -1.000000
# 25%       24.000000            1630.701667           3.000000
# 50%       33.000000            3108.209167           6.000000
# 75%       42.000000            5981.988333           7.000000
# max     8698.000000           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# count     54739.000000   54739.000000         54739.000000
# mean         22.910192      74.189335            21.054349
# std         130.296550     473.027027            14.840965
# min           0.000000       1.000000            -5.000000
# 25%           4.000000       8.000000            10.000000
# ...

# %%
#Checking the missing values
df.isnull().sum()
# Out:
# Month                           0
# Name                         5527
# Age                          2732
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                 6252
# Delay_from_due_date             0
# Num_of_Delayed_Payment       3829
# Changed_Credit_Limit            0
# Num_Credit_Inquiries            0
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance               649
# Credit_Score                29152
# dtype: int64

# %%
# Remove duplicate rows
df_unique = df.drop_duplicates()

# %%
df
# Out:
#          Month               Name   Age          SSN     Occupation  \
# 0       August          le Stevem  50.0  598-28-8368        Manager
# 1         July           Raymondl  32.0  887-23-0031   Entrepreneur
# 2         June             Harryw  32.0  966-30-5287        _______
# 3         June           Jessican  19.0  220-63-1416     Accountant
# 4          May               Dayz  41.0  277-13-7658         Doctor
# ...        ...                ...   ...          ...            ...
# 54734     June  Kiyoshi Takenakar  48.0  216-36-8255  Media_Manager
# 54735  January            Kerbere  21.0    #F%$D@*&8         Doctor
# 54736    March             Carewn  32.0  398-22-8099      Developer
# 54737     June               Nius  31.0  893-44-1748       Mechanic
# 54738    April          Tetsushiz  44.0  856-06-6147     Journalist
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          72099.14            5842.350694                  4
# ...

# %%
# Set pandas to display all columns
pd.set_option('display.max_columns', None)

# Now when you print the DataFrame, all columns should be visible
print(df)
# Out:
#          Month               Name   Age          SSN     Occupation  \
# 0       August          le Stevem  50.0  598-28-8368        Manager
# 1         July           Raymondl  32.0  887-23-0031   Entrepreneur
# 2         June             Harryw  32.0  966-30-5287        _______
# 3         June           Jessican  19.0  220-63-1416     Accountant
# 4          May               Dayz  41.0  277-13-7658         Doctor
# ...        ...                ...   ...          ...            ...
# 54734     June  Kiyoshi Takenakar  48.0  216-36-8255  Media_Manager
# 54735  January            Kerbere  21.0    #F%$D@*&8         Doctor
# 54736    March             Carewn  32.0  398-22-8099      Developer
# 54737     June               Nius  31.0  893-44-1748       Mechanic
# 54738    April          Tetsushiz  44.0  856-06-6147     Journalist
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0          72099.14            5842.350694                  4
# ...

# %%
print(df.head())
# Out:
#     Month       Name   Age          SSN    Occupation Annual_Income  \
# 0  August  le Stevem  50.0  598-28-8368       Manager      72099.14
# 1    July   Raymondl  32.0  887-23-0031  Entrepreneur      17443.94
# 2    June     Harryw  32.0  966-30-5287       _______     15186.175
# 3    June   Jessican  19.0  220-63-1416    Accountant     177696.92
# 4     May       Dayz  41.0  277-13-7658        Doctor     19188.055
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            5842.350694                  4                3              2
# 1            1714.661667                 10               10             21
# 2            1527.514583                  4                3              6
# 3           15090.076667                  5                5              9
# 4            1358.004583                  5                4              2
#
#   Num_of_Loan                                       Type_of_Loan  \
# ...

# %% [markdown]
# # Univariate

# %%
# Convert numerical columns with incorrect dtype to numeric, replacing errors
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df['Annual_Income'] = pd.to_numeric(df['Annual_Income'].str.replace('[^0-9]', ''), errors='coerce')
df['Monthly_Balance'] = pd.to_numeric(df['Monthly_Balance'].str.replace('[^0-9]', ''), errors='coerce')

# %% [markdown]
# ## Categoric

# %%
# NOTE: Count represents how many times or how frequent that month appears in the data , it goes the same way with other charts.


# Note theres 14 categorical columns only Plotting some of the most important categorical columns 
categorical_cols = ['Month', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour']

# Plot categorical columns
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Count of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
categorical_cols =['Occupation']

# %%
#pie chart for occupation

df["Occupation"].value_counts().plot.pie(autopct='%1.1f%%').set(title='Occupation')
plt.show()

# %% [markdown]
# # Numeric

# %%
numerical_cols = ['Age']

# %%
# Convert 'Age' to numeric, coerce errors (invalid strings will be turned into NaN)
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# Select the first 10 rows
df_top_10 = df.head(10)

# Create a countplot for the 'Age' column (for the first 10 rows)
plt.figure(figsize=(10, 6))
sns.countplot(data=df_top_10, x='Age')
plt.title('Count Plot of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Numerical columns to plot using histplot
numerical_cols = [ 'Monthly_Inhand_Salary', 'Delay_from_due_date',
                  'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio',
                  'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance', 'Credit_Score','Num_Bank_Accounts']

# %%
# Plot numerical columns
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# # BIVARIATE

# %%
# This can provide insights into income disparities across different job roles.
df.groupby("Occupation")['Annual_Income'].mean().sort_values(ascending=False)
# Out:
# Occupation
# Lawyer           216345.039797
# Scientist        206707.104649
# Doctor           199820.198514
# Journalist       192688.454456
# Engineer         189058.861995
# Entrepreneur     186926.097779
# _______          184206.147579
# Musician         183399.335176
# Media_Manager    182105.629917
# Teacher          178668.822969
# Writer           173042.701363
# Manager          171523.903986
# Accountant       163737.560411
# Mechanic         163029.734166
# Developer        154549.548955
# Architect        128340.671732
# Name: Annual_Income, dtype: float64

# %%
# Group the DataFrame by the 'Month' column and calculate the mean of 'Monthly_Inhand_Salary' for each month.
df.groupby("Month")['Monthly_Inhand_Salary'].mean().sort_values(ascending=False)
# Out:
# Month
# January     4259.084420
# February    4226.073076
# August      4216.129463
# May         4212.805222
# July        4209.076209
# March       4189.373716
# June        4165.020621
# April       4163.384098
# Name: Monthly_Inhand_Salary, dtype: float64

# %%
df.columns
# Out:
# Index(['Month', 'Name', 'Age', 'SSN', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %% [markdown]
# ## Target distribution

# %%
#This count plot displays how many times each unique Credit_Score value occurs in the dataset

# Plot the count of each Credit_Score category
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Credit_Score')
plt.title('Count of Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Count')
plt.show()

# %%
# Plot scatter plot of Credit_Score vs. Annual_Income

# HERE the plot visualizes how Annual Income relates to Credit Score.

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Credit_Score', y='Annual_Income')
plt.title('Credit Score vs. Annual Income')
plt.xlabel('Credit Score')
plt.ylabel('Annual Income')
plt.show()

# %% [markdown]
# ## The relation between Monthly inhand salary and Outstanding Debt

# %%
# Bivariate scatter plot for 'Monthly_Inhand_Salary' vs 'Outstanding_Debt'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Monthly_Inhand_Salary', y='Outstanding_Debt')
plt.title('Monthly Inhand Salary vs Outstanding Debt')
plt.xlabel('Monthly Inhand Salary')
plt.ylabel('Outstanding Debt')
plt.show()

# %% [markdown]
# ## Monthly_inhand_Salary per Occupation

# %%
# Box plot for 'Occupation' vs 'Monthly_Inhand_Salary'
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Occupation', y='Monthly_Inhand_Salary')
plt.title('Occupation vs Monthly Inhand Salary')
plt.xlabel('Occupation')
plt.ylabel('Monthly Inhand Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Corrolation between features

# %%
# do heatmap for numeric columns (, ,)
import seaborn as sns
import matplotlib.pyplot as plt

# Select specific numeric columns
columns_of_interest = ['Credit_Score','Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']
numeric_df = df[columns_of_interest]

# Ensure these columns are numeric and convert if necessary
numeric_df = numeric_df.apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN values to ensure we can compute the correlation matrix
numeric_df = numeric_df.dropna()

# Calculate correlation
heatmap = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap for numerical columns')
plt.show()

# %% [markdown]
# ## there appear to be strong correlations between several features in the provided correlation matrix:
#
# -Monthly Inhand Salary has a strong positive correlation with Monthly_Balance (0.71) and Amount_invested_monthly (0.64), suggesting that individuals with higher salaries tend to have higher balances and invest more.
#
# -Outstanding_Debt has strong negative correlations with Credit_Score (-0.55), Delay_from_due_date (-0.53), and Monthly_Balance (-0.36), indicating that individuals with higher debt tend to have lower credit scores, are more likely to delay payments, and have lower monthly balances.
#
# -Delay_from_due_date has a strong positive correlation with Outstanding_Debt (0.58), suggesting that individuals who delay payments are more likely to have higher outstanding debt.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# #### This dataset encompasses various attributes that collectively provide a comprehensive view of an individual's financial profile and credit behavior.
#
#
#
#
# -Personal Information:
# Month: Indicates the time frame of the data, which can help identify trends over time.
# Name, Age, SSN, Occupation: These columns provide demographic details that are crucial for understanding the socio-economic context of the individuals.
#
#
#
# -Income and Salary:
# Annual_Income & Monthly_Inhand_Salary: These metrics offer insights into the individual’s earning capacity, which is essential for assessing financial stability and budgeting.
#
#
#
#
# -Debt and Loan Information:
# Num_of_Loan, Type_of_Loan, Outstanding_Debt: These attributes reflect the individual's borrowing behavior and current debt obligations, which are critical for evaluating financial health.
#
#
#
#
# -Delay_from_due_date:
# This column indicates payment punctuality, directly influencing creditworthiness.
#
#
#
#
# -Credit Behavior:
# Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Utilization_Ratio, Credit_History_Age: These metrics provide insights into the individual’s credit management practices, including how they utilize credit, their history of inquiries, and the length of their credit history.
#
#
#
#
# -Payment_of_Min_Amount: This indicates whether the individual meets minimum payment requirements, which is vital for maintaining a good credit score.
#
#
#
#
# -Financial Management:
# Total_EMI_per_month, Amount_invested_monthly: These columns help analyze the monthly financial commitments and investments, providing a picture of cash flow management.
#
#
#
#
# -Monthly_Balance: This reflects the individual’s financial status after accounting for income and expenses.
#
#
#
#
# -Credit Score and Payment Behavior:
# Credit_Score, Payment_Behaviour: These are critical indicators of creditworthiness and payment reliability, which lenders use to assess risk.
